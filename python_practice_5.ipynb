# %% [markdown]
# # I. OOP

# %% [markdown]
# 1. (6б). Створіть клас Building, додайте три атрибути, один з яких має значення за замовчуванням та два методи на свій розсуд.

# %%
class Building:

    def __init__(self, floors, area, material="concrete"):
        self.floors=floors
        self.area=area
        self.material=material

    def toString(self):
        return f"Building floors={self.floors}, area={self.area}, material={self.material}"

    def copy(self, building):
        return Building(building.floors, building.area, building.material)

# %% [markdown]
# 2. (2б). Створіть два обʼєкти цього класу, де один з обʼєктів створюється із дефолтним значенням атрибуту. На одному обʼєкті отримайте значення його атрибуту, а на іншому викличте один з його методів.

# %%
b1 = Building(25, 160)
b2 = Building(30, 200, "brick")
print(b1.floors)
print(b2.toString())
# Out:
# 25
# Building floors=30, area=200, material=brick

# %% [markdown]
# 3. (5б). Створіть клас, де атрибути мають різні рівні доступу. Спробуйте отримати їхні значення та опишіть результати.

# %%
class Proprietary:

    def __init__(self):
        self.public="public attr"
        self.__private="private attr"

p1 = Proprietary()
print(p1.public)
try:
  print(p1.__private)
except AttributeError:
  print("Exception")
# Out:
# public attr
# Exception

# %% [markdown]
# 4. (7б). Як ви розумієте термін self? Для чого використовується метод __init __?

# %% [markdown]
# self - самопосилання на об'єкт; __init__ = конструктор класу

# %% [markdown]
# 5. (9б). Створіть клас 3D-фігура без атрибутів, з методом get_volume для отримання об'єму фігури, що повертає 0 та __add __, який приймає self та other в якості аргументів, а повертає суму об'ємів 3d-фігур self та other.

# %%
class Form3D:

    def get_volume(self):
        return 0

    def __add__(self, other):
        if isinstance(other, Form3D):
            return self.get_volume() + other.get_volume()

# %% [markdown]
# 6. (11б). Створіть 2 дочірніх класи від 3d-фігура: Циліндр та Куб, які мають атрибути, необхідні для розрахунку об'єму. Визначте метод get_volume в кожному з них так, щоби вони розраховували об'єм у залежності від формули для кожного типу фігури. Створіть обʼєкт класу Циліндр та обʼєкт класу Куб. Виконайте операцію суми за допомогою оператора + між ними, аби знайти сумарний об'єм.

# %%
class Cube(Form3D):

    def __init__(self, side):
        self.side = side

    def get_volume(self):
        return self.side**3


class Cylinder(Form3D):

    def __init__(self, radius, height):
        self.radius = radius
        self.height = height

    def get_volume(self):
        return self.radius**2 * self.height * 3.14

cube = Cube(4)
cylinder = Cylinder(1, 3)
print(cube.get_volume())
print(cylinder.get_volume())
print(cube + cylinder)
# Out:
# 64
# 9.42
# 73.42

# %% [markdown]
# 7. (3б). Продемонструйте різницю між isinstance та issubclass.

# %%
cube = Cube(4)
cylinder = Cylinder(1, 3)

print(isinstance(cube, Cube))
print(isinstance(cube, Form3D))
print(isinstance(cube, Cylinder))

print(issubclass(Cube, Form3D))
print(issubclass(Cylinder, Form3D))
print(issubclass(Form3D, Cube))
# Out:
# True
# True
# False
# True
# True
# False

# %% [markdown]
# 8. (13б). Створіть клас EWallet з приватними атрибутами balance та id. Реалізуйте методи поповнення та зняття коштів, забезпечивши належну інкапсуляцію. Підказка: використовуйте декоратори property та setter.

# %%
class EWallet:

    def __init__(self, wid, balance=0):
        self.__id = wid
        self.__balance = balance

    @property
    def id(self):
        return self.__id

    @property
    def balance(self):
        return self.__balance

    @balance.setter
    def balance(self, val):
        if val >= 0:
            self.__balance = val
            return True
        return False

    def put(self, val):
        if val >= 0:
            self.__balance += val
            return True
        return False

    def get(self, val):
        if val <= 0 or val > self.__balance:
            return False
        self.__balance -= val
        return True

w1 = EWallet("w1", 75)
print(w1.id)
print(w1.balance)
w1.put(50)
print(w1.balance)
# Out:
# w1
# 75
# 125

# %% [markdown]
# 9. (11б). Створіть клас ShoppingCart, який містить список об'єктів типу Item. Реалізуйте методи для додавання айтемів, їх видалення та відображення списку айтемів.

# %%
class Item:

    def __init__(self, name):
        self.name = name

    def __str__(self):
        return f"{self.name}"

class ShoppingCart:

    def __init__(self):
        self.items = []

    def add(self, item):
        if isinstance(item, Item):
            self.items.append(item)

    def remove(self, item):
        if item in self.items:
            self.items.remove(item)

    def show(self):
        print("Items:")
        for item in self.items:
            print(item)

cart = ShoppingCart()
cart.add(Item("Bread"))
cart.add(Item("Sausage"))
cart.show()
# Out:
# Items:
# Bread
# Sausage

# %% [markdown]
# 10. (13б). Створіть клас Vehicle з атрибутами brand (manufacturer) та production_age. Створіть ще один клас Engine з такими атрибутами, як type (ex. petrol) та size (volume, litres). Створіть клас Car, який успадковує обидва класи Vehicle та Engine. Продемонструйте використання множинної спадковості, створивши обʼєкт класу Car та отримавши mro для цього класу.

# %%
class Vehicle:

    def __init__(self, brand, production_age):
        self.brand = brand
        self.production_age = production_age

class Engine:

    def __init__(self, type, size):
        self.type = type
        self.size = size

class Car(Vehicle, Engine):

    def __init__(self, brand, production_age, type, size):
        Vehicle.__init__(self, brand, production_age)
        Engine.__init__(self, type, size)

car = Car("Tavria", 30, "gas", 3.0)
print(Car.mro())
# Out:
# [<class '__main__.Car'>, <class '__main__.Vehicle'>, <class '__main__.Engine'>, <class 'object'>]

# %% [markdown]
# # II. Iterator

# %% [markdown]
# 11. (4б). Визначте рядок(str) з 4ма різними за значенням символами. Створіть ітератор на основі цього рядка. Викличте 5 разів функцію next на ітераторі, 4ри перших з них огорніть у ф-цію print().

# %%
st = "JAVA"
it = iter(st)

print(next(it))
print(next(it))
print(next(it))
print(next(it))

try:
    fifth = next(it)
except StopIteration:
    print("Exception")
# Out:
# J
# A
# V
# A
# Exception

# %% [markdown]
# А що якщо викликати цю ж функцію на рядку?

# %%
st = "JAVA"

try:
    next(st)
except TypeError:
    print("Exception")
# Out:
# Exception

# %% [markdown]
#  12. (5б). Опишіть своїми словами в одному реченні, як ви розумієте різницю між ітерабельними обʼєктами та ітераторами (можна на прикладі).

# %% [markdown]
# ітерувати можна по ітератору, а ітератор в свою чергу створюється і ітерабельного об'єкта; один такий об'єкт може мати кілька ітераторів

# %% [markdown]
# 13. (11б). Створіть клас, що має визначений Iterator Protocol та при кожному виклику next повертає назву дня тижня, поки вони не вичерпаються. Зверніть увагу, що порядок має значення.

# %%
class Week:
    def __init__(self):
        self.days = ("Понеділок", "Dienstag", "Merccredi", "Torsdag", "Viernes", "Sabato", "Sunday")
        self.current = 0

    def __iter__(self):
        return self

    def __next__(self):
        if self.current >= len(self.days):
            raise StopIteration
        day = self.days[self.current]
        self.current+=1
        return day

week = Week()
for day in week:
    print(day)
# Out:
# Понеділок
# Dienstag
# Merccredi
# Torsdag
# Viernes
# Sabato
# Sunday

# %% [markdown]
# # Вітаю! Ви велика(ий) молодець, що впоралась(вся). Похваліть себе та побалуйте чимось приємним. Я Вами пишаюся.
